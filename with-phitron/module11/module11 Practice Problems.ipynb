# %%
import torch

x = torch.tensor([2.0], requires_grad=True)
y = x**2 + 3*x + 1
y.backward()

# %%
x.grad
# Out:
# tensor([7.])

# %%
x = torch.tensor([2.0])
y = x**2
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 x = torch.tensor([2.0])
#       2 y = x**2
# ----> 3 y.backward()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\autograd\__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
# ...
